# %%
print("Day 1 Start")

# %%
install yfinance

# %%
pip install yfinance

# %%
import yfinance as yf

data = yf.download ("SPY", start="2025-01-01", end="2024-01-01")
print(data.head())

# %%
import yfinancee as yf

data = yf.download ("SPY", start="2024-01-01", end="2025-01-01")
print(data.head())

# %%
import yfinance as yf

data = yf.download ("SPY", start="2024-01-01", end="2025-01-01")
print(data.head())

# %%
import yfinance as yf

spy = yf.Ticker("SPY")
data = spy.history(start="2025-01-01", end="2026-01-01")
print(data.head())

# %%
pip install --upgrade yfinance

# %%
import yfinance as yf

data = yf.download ("SPY", start="2025-01-01", end="2026-01-01")
print(data.head())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open    Volume
# Ticker             SPY         SPY         SPY         SPY       SPY
# 2025-01-02  576.280334  582.677525  572.199517  580.962415  50204000
# 2025-01-03  583.485779  584.126448  578.044689  579.128997  37888500
# 2025-01-06  586.846985  591.124954  585.112141  587.744007  47679400
# 2025-01-07  580.213257  589.202846  578.389734  588.877548  60393100
# 2025-01-08  581.060974  582.135415  576.832338  580.282292  47304700

# %%
print(data.tail())
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker             SPY         SPY         SPY         SPY       SPY
# 2025-12-24  688.499695  688.948481  685.926705  686.076320  39445600
# 2025-12-26  688.429871  689.776169  687.392725  688.758989  41613300
# 2025-12-29  685.976562  687.322922  684.201442  685.667409  62559500
# 2025-12-30  685.138916  686.684682  684.710094  685.577720  47160700
# 2025-12-31  680.062744  685.487930  679.853355  685.268559  74144800

# %%
print(data.shape())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(data.shape())
#
# TypeError: 'tuple' object is not callable

# %%
print(data.shape)
# Out:
# (250, 5)

# %%
print(data.describe())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(data.describe())
#
# NameError: name 'data' is not defined

# %%
import yfinance as yf

data = yf.download ("SPY", start="2025-01-01", end="2026-01-01")
print(data.describe())
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price        Close        High         Low        Open        Volume
# Ticker         SPY         SPY         SPY         SPY           SPY
# count   250.000000  250.000000  250.000000  250.000000  2.500000e+02
# mean    614.198195  617.339555  610.341542  614.023396  7.244500e+07
# std      47.447117   46.415342   48.741463   47.790472  2.913371e+07
# min     490.853088  515.787225  476.339440  483.645699  2.604870e+07
# 25%     581.479172  585.548430  577.135380  581.219602  5.766440e+07
# 50%     615.345520  617.829451  612.762405  616.669283  6.812535e+07
# 75%     658.778961  662.042848  654.944427  658.547755  8.113838e+07
# max     688.499695  689.776169  687.392725  688.758989  2.566114e+08

# %%
data['daily_return'] = data['close'].pct_change()
print(data['daily_return'].describe())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'close'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 data['daily_return'] = data['close'].pct_change()
#       2 print(data['daily_return'].describe())
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/pandas/core/frame.py:4101, in DataFrame.__getitem__(self, key)
#    4099 if is_single_key:
#    4100     if self.columns.nlevels > 1:
# -> 4101         return self._getitem_multilevel(key)
#    4102     indexer = self.columns.get_loc(key)
#    4103     if is_integer(indexer):
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/pandas/core/frame.py:4159, in DataFrame._getitem_multilevel(self, key)
#    4157 def _getitem_multilevel(self, key):
#    4158     # self.columns is a MultiIndex
# -> 4159     loc = self.columns.get_loc(key)
#    4160     if isinstance(loc, (slice, np.ndarray)):
#    4161         new_columns = self.columns[loc]
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/pandas/core/indexes/multi.py:3040, in MultiIndex.get_loc(self, key)
#    3037     return mask
#    3039 if not isinstance(key, tuple):
# -> 3040     loc = self._get_level_indexer(key, level=0)
#    3041     return _maybe_to_slice(loc)
#    3043 keylen = len(key)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/pandas/core/indexes/multi.py:3391, in MultiIndex._get_level_indexer(self, key, level, indexer)
#    3388         return slice(i, j, step)
#    3390 else:
# -> 3391     idx = self._get_loc_single_level_index(level_index, key)
#    3393     if level > 0 or self._lexsort_depth == 0:
#    3394         # Desired level is not sorted
#    3395         if isinstance(idx, slice):
#    3396             # test_get_loc_partial_timestamp_multiindex
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/pandas/core/indexes/multi.py:2980, in MultiIndex._get_loc_single_level_index(self, level_index, key)
#    2978     return -1
#    2979 else:
# -> 2980     return level_index.get_loc(key)
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'close'

# %%
data['daily_return'] = data['Close'].pct_change()
print(data['daily_return'].descript())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/fx/plgr85q13hv0hk1cb9wjw7cm0000gn/T/ipykernel_76964/4093988660.py in ?()
#       1 data['daily_return'] = data['Close'].pct_change()
# ----> 2 print(data['daily_return'].descript())
#
# /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'descript'

# %%
data['daily_return'] = data['Close'].pct_change()
print(data['daily_return'].describe())
# Out:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: daily_return, dtype: float64

# %%
print(data.columns)
# Out:
# MultiIndex([(       'Close', 'SPY'),
#             (        'High', 'SPY'),
#             (         'Low', 'SPY'),
#             (        'Open', 'SPY'),
#             (      'Volume', 'SPY'),
#             ('daily_return',    '')],
#            names=['Price', 'Ticker'])

# %%
data.columns = ['Close', 'High', 'Low', 'Open', 'Volume']
data['daily_return'] = data['Close'].pct_change()
print(data['daily_return'].describe())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 data.columns = ['Close', 'High', 'Low', 'Open', 'Volume']
#       2 data['daily_return'] = data['Close'].pct_change()
#       3 print(data['daily_return'].describe())
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/pandas/core/generic.py:6313, in NDFrame.__setattr__(self, name, value)
#    6311 try:
#    6312     object.__getattribute__(self, name)
# -> 6313     return object.__setattr__(self, name, value)
#    6314 except AttributeError:
#    6315     pass
#
# File properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/pandas/core/generic.py:814, in NDFrame._set_axis(self, axis, labels)
#     809 """
#     810 This is called from the cython code when we set the `index` attribute
#     811 directly, e.g. `series.index = [1, 2, 3]`.
#     812 """
#     813 labels = ensure_index(labels)
# --> 814 self._mgr.set_axis(axis, labels)
#     815 self._clear_item_cache()
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/pandas/core/internals/managers.py:238, in BaseBlockManager.set_axis(self, axis, new_labels)
#     236 def set_axis(self, axis: AxisInt, new_labels: Index) -> None:
#     237     # Caller is responsible for ensuring we have an Index object.
# --> 238     self._validate_set_axis(axis, new_labels)
#     239     self.axes[axis] = new_labels
#
# File /opt/homebrew/Caskroom/miniconda/base/lib/python3.11/site-packages/pandas/core/internals/base.py:98, in DataManager._validate_set_axis(self, axis, new_labels)
#      95     pass
#      97 elif new_len != old_len:
# ---> 98     raise ValueError(
#      99         f"Length mismatch: Expected axis has {old_len} elements, new "
#     100         f"values have {new_len} elements"
#     101     )
#
# ValueError: Length mismatch: Expected axis has 6 elements, new values have 5 elements

# %%
raw = yf.download("SPY", start="2025-01-01", end="2026-01-01")
new_data = raw.droplevel('Ticker', axis=1)
new_data['daily_return'] = new_data['Close'].pct_change()

print (new_data['daily_return'].describe())
# Out:
# [*********************100%***********************]  1 of 1 completed
# count    249.000000
# mean       0.000740
# std        0.012299
# min       -0.058543
# 25%       -0.003564
# 50%        0.001376
# 75%        0.005761
# max        0.105019
# Name: daily_return, dtype: float64

# %%
print(new_data['daily_return'].isna().sum())
# Out:
# 1
