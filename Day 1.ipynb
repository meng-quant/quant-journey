# %%
print("Day 1 Start")
# Out:
# Day 1 Start

# %%
install yfinance
# Out:
#   Cell In[2], line 1
#     install yfinance
#             ^
# SyntaxError: invalid syntax

# %%
pip install yfinance

# %%
import yfinance as yf

data = yf.download ("SPY", start="2025-01-01", end="2024-01-01")
print(data.head())
# Out:
# $SPY: possibly delisted; no price data found  (1d 2025-01-01 -> 2024-01-01) (Yahoo error = "Invalid input - start date cannot be after end date. startDate = 1735707600, endDate = 1704085200")
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: possibly delisted; no price data found  (1d 2025-01-01 -> 2024-01-01) (Yahoo error = "Invalid input - start date cannot be after end date. startDate = 1735707600, endDate = 1704085200")
# Empty DataFrame
# Columns: [(Adj Close, SPY), (Close, SPY), (High, SPY), (Low, SPY), (Open, SPY), (Volume, SPY)]
# Index: []

# %%
import yfinancee as yf

data = yf.download ("SPY", start="2024-01-01", end="2025-01-01")
print(data.head())

# %%
import yfinance as yf

data = yf.download ("SPY", start="2024-01-01", end="2025-01-01")
print(data.head())

# %%
import yfinance as yf

spy = yf.Ticker("SPY")
data = spy.history(start="2025-01-01", end="2026-01-01")
print(data.head())

# %%
pip install --upgrade yfinance

# %%
import yfinance as yf

data = yf.download ("SPY", start="2025-01-01", end="2026-01-01")
print(data.head())

# %%
print(data.tail())

# %%
print(data.shape())

# %%
print(data.shape)

# %%
print(data.describe())

# %%
import yfinance as yf

data = yf.download ("SPY", start="2025-01-01", end="2026-01-01")
print(data.describe())

# %%
data['daily_return'] = data['close'].pct_change()
print(data['daily_return'].describe())

# %%
data['daily_return'] = data['Close'].pct_change()
print(data['daily_return'].descript())

# %%
data['daily_return'] = data['Close'].pct_change()
print(data['daily_return'].describe())

# %%
print(data.columns)

# %%
data.columns = ['Close', 'High', 'Low', 'Open', 'Volume']
data['daily_return'] = data['Close'].pct_change()
print(data['daily_return'].describe())

# %%
raw = yf.download("SPY", start="2025-01-01", end="2026-01-01")
new_data = raw.droplevel('Ticker', axis=1)
new_data['daily_return'] = new_data['Close'].pct_change()

print (new_data['daily_return'].describe())

# %%
print(new_data['daily_return'].isna().sum())

# %%
print(new_data['daily_return'].head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(new_data['daily_return'].head())
#
# NameError: name 'new_data' is not defined
